# %%
import pyodbc
import pandas as pd
server = 'AJAY\SQLEXPRESS' 
database = 'CEN414' 
username = 'AJAY\Ajayi Emmanuel' 
password = 'CEN414'  
conn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+'; Trusted_Connection=yes;')
cursor = conn.cursor()
query = "SELECT * FROM dbo.datat;"
df = pd.read_sql(query, conn)
df
# Out:
#                              column1  column2  column3  column4  column5  \
# 0                            Country     2018     2017     2016     2015
# 1                            Algeria  3981219  2436503  2440097  2656731
# 2                             Angola     2820     2827     2924     2709
# 3                            Burundi    22751     8060     7980     6421
# 4                           Cameroon      938      923      908      897
# 5                               Chad     1798     1870     1742      965
# 6   Democratic Republic of the Congo     6309     6439     6755     7342
# 7                              Egypt  8800000  8421071  9342538  9607736
# 8                            Eritrea    28939    25000    25000    25000
# 9                           Ethiopia  4238836  4796031  4537852  4650934
# 10                             Kenya   336600   165200   214700   238600
# 11                           Lesotho     9058     8851     4690     7069
# ...
